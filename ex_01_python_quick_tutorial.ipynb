# %%
                 '''老师，作业里有我通过课堂和课下学习整理的知识点和一些练习题，以及授课网站中出现的题目,所以看起来会有一点多，
          
                
                
                                         练习题和知识点有加以区分，方便老师检查作业'''





#print函数
#打印字符串
print('Hello python!') 
print("Hello world!")
print("_"*50)
print("编程让设计更具创造力！")
print("Everybody should learn how to code a computer, because it teaches you how to think, and allows designers more creative!")
#可以输出含有运算符表达式,含有操作数和运算符称为表达式
print('加：',3+3) 
print('减：',3-1)
print('乘：',3*3)
print('除：',3/3)
print('整除：', 3//2)
print('余数：',3%2)
print('幂：',3**3)

#可以输出数字
print(98.5)
print(520)

#将数据输出到文件中  指定位置存在且使用file=fp
fp=open('D:/text.txt','a+') #a+的含义：如果文件不存在就创建文件，如果存在就在文件内容后面追加
print('hello world',file=fp)
fp.close()

#不进行换行输出，输出内容在一行当中（逗号分隔）
print('hello','world','python')

#input(函数)
#输入函数input() value为str类型
question=input('纸媒没落了么？')
print(question,type(question))

#两种运算符
a=int(input('请输入一个加数:'))
#a=int(a) #将转换之后的结果存储到a中
b=int(input('请输入另一个加数:'))
#b=int(b)
print(a+b)
print(type(a),type(b))
# Out:
# Hello python!
# Hello world!
# __________________________________________________
# 编程让设计更具创造力！
# Everybody should learn how to code a computer, because it teaches you how to think, and allows designers more creative!
# 加： 6
# 减： 2
# 乘： 9
# 除： 1.0
# 整除： 1
# 余数： 1
# 幂： 27
# 98.5
# 520
# hello world python
# 纸媒没落了么？ 嗯
# 嗯 <class 'str'>
# 请输入一个加数: 3
# 请输入另一个加数: 3
# 6
# <class 'int'> <class 'int'>

# %%
#变量及赋值
'''func=2*x+1 
x=5
print(func)'''#当程序逐行从上至下运行时，注意变量定义的顺序
x=5
func=2*x+1 
print(func)

#知识点
def fun(a,b):
    c=a+b #c就称为局部变量，因为c在是函数体内进行定义的变量，a,b为函数的形参，作用范围也是函数的内部，相当于变量内部
    print(c)
#print(c)
#print(a) 报错原因：超出作用域

name='龚俊' #name的作用范围为函数的内外部，称为全局变量
print(name)
def fun():
    print(name)
#调用函数
fun2()

def fun3():
    global age #局部变量通过global声明转化为全局变量
    age=20
    print(age)
fun3()
print(age)

# %%
#练习题
x=5.0
monadic_equation=2*x+1
print("monadic_equation=",monadic_equation)
print("monadic_equation=%.2f"%monadic_equation) #%字符串格式化方法
print("monadic_equation={:.2f}".format(monadic_equation)) #format()字符串格式化方法

#西安经纬度练习
city_name="Xi'an"
coordinate_longitude=108.942292
coordiante_latitude=34.261013
print("The longitude of the Xi'an coordinate is {lon:.2f}, and the latitude is {lat}.".format(lon=coordinate_longitude,lat=coordiante_latitude))

#函数练习题
x,y,b=9,4,2 #系列解包赋值
func_2='4*x+2*y-3b'
print('func={}'.format(x,y,b,func_2))
# Out:
# monadic_equation= 11.0
# monadic_equation=11.00
# monadic_equation=11.00

# %%
#算术运算符
print(1+1)
print(2-1)
print(2*3)
print(2/2) #除法
print(11//2) #整除运算，去尾
print(11%2) #取余运算,value为余数
print(2**8) #幂
print(9//4)
print(-9//-4)
print(-9//4)
print(9//-4) #向下取整
print(9%-4)
print(-9%4) #余数=被除数-除数*商

#赋值运算符，从右往左
a=3+4
print(a)
a=b=c=20
print(a,id(a))
print(b,id(b))
print(c,id(c)) #链式赋值
a=20
a+=30 #相当于a=a+30
print(a)
a-=10
print(a)
a*=3
print(a)
a/=2
print(a)
a//=3
print(a)
print(type(a))
a%=3
print(a)
print(type(a)) #参数赋值
a,b,c=10,20,30
print(a,b,c) #系列解包赋值，变量与值一一对应
print('交换之前:',a,b)
a,b=b,a
print('交换之后:',a,b)

#比较运算符
a,b=10,20
print(a>b) #bool类型
print(a<=b)
print(a==b) #false
print(a!=b)
'''一个=称为赋值运算符，两个==称为比较运算符
   一个变量由三部分组成，标识，类型，值
     ==比较的是值
     is比较标识'''

a=10
b=20
print(a==b) #value相同
print(a is b) #id相同
lst=[11,22,33,44]
lst2=[11,22,33,44]
print(lst==lst2)
print(lst is lst2)
print(id(lst))
print(id(lst2))
print(lst is lst2)

#布尔运算符
a,b=1,2
print(a==1 and b==2)
print(a!=b and b<2)
print(a!=b and b==2) #同真则真，一假则假
print(a==b or b==2) #一真则真，同假则假
f=True
f2=False
print(not f)
print(not f2) #对运算数进行计算
s='helloworld'
print('w' in s)
print('w' not in s)

#位运算符 a
print(4&8) #按位与&，同为1时结果为1
print(4|8) #按位或|，同为0时结果为0
#移位
'''
左移位:高位溢出，低位补0,相当于*2
右移位:低位截断，高位补0，相当于/2
'''
print(4<<1) #左移位
print(4>>1) #右移位
print(4<<2)

#运算符的优先级
'''算术运算符>位运算符>比较运算>布尔运算'''
# Out:
# The longitude of the Xi'an coordinate is 108.94, and the latitude is 34.261013.

# %%
#转义字符
print('Hello\nworld')   #\+有转义功能的首字母     n→newline 换行
print('hello\tworld')
print('helloooo\tworld')
print('hello\rworld')
print('hello\bworld')
print('http:\\\\www.baidu.com')
print('老师说：\'大家好\'')

#原字符，加r或re,但最后一个字符不能是\,抑制转义字符
print(r'helllo\bworld')
# Out:
# func=9

# %%
#列表
lst_n=list(range(5,20,3)) #建立列表。range(start,stop,[,step])建立区间。
print(lst_n)
print("The list length={}".format(len(lst_n)))
print("Maximum value={}".format(max(lst_n)))
print("Minimum value={}".format(min(lst_n)))

#知识点：
#创建列表的第一种方式，方括号
['hello','world',98]
#创建函数的第二种方法，使用内置函数lst()
lst=list([98,99])

#空列表的创建方式
lst=[]
lst=list()

lst=['hello','world',98,'hello']
print(lst.index("hello"))

#print(lst.index('hello',1,3))

lst=['hello','world',98,'hello','world',1129]
print(lst[2])
# Out:
# [5, 8, 11, 14, 17]
# The list length=5
# Maximum value=17
# Minimum value=5

# %%
#分片
lst_s=list(map(chr,range(100,110)))
print(lst_s)
print("_"*50)
print("[3:6]->{}".format(lst_s[3:6]))
print("[-3:-1]->{}".format(lst_s[-3:-1]))
print("[-3:]->{}".format(lst_s[-3:]))
print("[:3]->{}".format(lst_s[:3]))
print("[:]->{}".format(lst_s[:]))

#知识点：

lst=[10,20,30,40,50,60,70,80]
#start=1,stop=6,step1
print(lst[1:6:1])
print('原列表',id(lst))
lst2=(lst[1:6:1])
print('切的片段',id(lst2))
print(lst[1:6]) #默认步长为一
print(lst[1:6:]) #默认步长为一
print(lst[1:6:2])  #步长为二
#step=2,stop=6
print(lst[:6:2])  #省略start
#start=1,step2
print(lst[1::2])

#range()
#内置函数range  用于生成一个整数序列
#range()的三种创建方式
'''只有一个参数'''
r=range(10)
print(r)
print(list(r)) #默认从0开始，且步长为1
'''有两个参数'''
r=range(1,10)
print(r)
print(list(r)) #默认步长为一
'''有三个参数'''
r=range(1,10,2)
print(list(r))

#存在性问题判定
print(10 not in r)
print(9 in r)

print(range(1,21,1))
print(range(1,101,1)) #所用内存相同
# Out:
# ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']
# __________________________________________________
# [3:6]->['g', 'h', 'i']
# [-3:-1]->['k', 'l']
# [-3:]->['k', 'l', 'm']
# [:3]->['d', 'e', 'f']
# [:]->['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
help(map) #用help()方法查看说明
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
help(chr)
# Out:
# Help on built-in function chr in module builtins:
#
# chr(i, /)
#     Return a Unicode string of one character with ordinal i; 0 <= i <= 0x10ffff.

# %%
#带有步长参数的分片 
print(lst_s)
print("_"*50)
print("[0:10:2]->{}".format(lst_s[0:10:2]))
print("[::3]->{}".format(lst_s[::3]))
print("[9:3:-2]->{}".format(lst_s[9:3:-2]))
print("[20:3:-2]->{}".format(lst_s[20:3:-2]))
print("[7::-2]->{}".format(lst_s[7::-2]))
print("[:3:-2]->{}".format(lst_s[:3:-2]))

#知识点：
lst=[10,20,30,40,50,60,70,80]
#start=1,stop=6,step1
print(lst[1:6:1])
print('原列表',id(lst))
lst2=(lst[1:6:1])
print('切的片段',id(lst2))
print(lst[1:6]) #默认步长为一
print(lst[1:6:]) #默认步长为一
print(lst[1:6:2])  #步长为二
#step=2,stop=6
print(lst[:6:2])  #省略start
#start=1,step2
print(lst[1::2])
# Out:
# ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']
# __________________________________________________
# [0:10:2]->['d', 'f', 'h', 'j', 'l']
# [::3]->['d', 'g', 'j', 'm']
# [9:3:-2]->['m', 'k', 'i']
# [20:3:-2]->['m', 'k', 'i']
# [7::-2]->['k', 'i', 'g', 'e']
# [:3:-2]->['m', 'k', 'i']

# %%
#列表操作
print(lst_s)
print("_"*50)
lst_s[5]=99 #元素赋值
print("lst_s[5]=99->{}".format(lst_s))
lst_none=lst_s+[None]*6
print("lst_s+[None]*6->{}".format(lst_none))
lst_none[13]=2015
print("lst_none[13]=2015->{}".format(lst_none))
lst_none[-6:-3]=list(range(100,104,2)) #分片赋值
print("lst_none[-6:-3]=list(range(100,104,2))->{}".format(lst_none))
lst_none[1:1]=[0,0,0,12]
print("lst_none[1:1]=[0,0,0,12]->{}".format(lst_none))
del lst_none[-2:] #删除元素
print("del lst_none[-2:]->{}".format(lst_none))

lst_s_2=list(map(chr,range(100,105)))
print(lst_s_2)
print("_"*50)
lst_s_2.append(99) #单个元素的增加
print("lst_s_2.append(99)->{}".format(lst_s_2))
lst_s_2.append(list(range(50,80,5))) 
print("lst_s_2.append(list(range(50,80,5)))->{}".format(lst_s_2))
lst_spechars=['*',')','*']
lst_s_2.extend(lst_spechars) 
print("lst_s_2.extend(lst_spechars)->{}".format(lst_s_2))
print("lst_s_2.count('*')={}".format(lst_s_2.count('*')))
print("lst_s_2.index('e')={}".format(lst_s_2.index('e')))
lst_s_2.insert(2,[1000,1200,1500])
print("lst_s_2.insert(2,[1000,1200,1500])->{}".format(lst_s_2))
print("lst_s_2.pop(7)_popup->{}".format(lst_s_2.pop(7)))
print("lst_s_2.pop(7)_retention->{}".format(lst_s_2))
lst_s_2.remove('*')
print("lst_s_2.remove('*')_retention->{}".format(lst_s_2))
list_n_2=[2,42,6,95,4,3]
list_n_2.sort()
print("list_n_2.sort()->{}".format(list_n_2))


#
#添加元素的四种方法
#使用attend（）列表末尾添加对象
lst=[10,20,30]
print('添加元素之前',lst,id(lst))
lst.append(100)
print('添加元素之后',lst ,id(lst)) #id相同

#使用extend（）在列表末尾至少添加一个元素
'''添加多个元素
lst2=['gongjun','shuaige']
lst.append(lst2)
print(lst)''' #程序将列表作为一个元素添加到列表的末尾，故更换方法
lst2=['gongjun','shuaige']
lst.extend(lst2)
print(lst)

#使用insert（）在任意位置插入元素
lst.insert(1,90)
print(lst)
#用切片的方法在列表的任意位置添加至少一个元素
lst3=['魏化俊','李子维']
lst[1:]=lst3
print(lst)

#remove（） 从列表中移除一个元素，当重复出现时，移除第一个
lst=[10,20,30,40,50,60,30]
lst.remove(30)
print(lst)
#pop() 删除一个指定索引位置上的元素，不指定则删除最后一个
lst.pop(1)
print(lst)
#lst.pop(5) #pop index out of range
lst.pop()
print(lst) #如果不指定索引，则删除列表中的最后一个元素
#切片操作，删除至少一个元素，将产生一个新的列表对象
new_lst=lst[1:3]
print('原列表',lst)
print('切片后的列表',new_lst)
#不产生新的列表对象，而是删除原列表的内容
lst[1:3]=[]
print(lst)
#clear 清楚列表中的所有元素
lst.clear()
print(lst)
#del语句将列表对象删除
del lst
#print(lst) #name 'lst' is not defined 列表已被删除

lst=[10,20,30,40]
#一次修改一个值
lst[2]=100
print(lst)
lst[1:3]=[300,400,500]
print(lst) #修改列表中的多个值
# Out:
# ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']
# __________________________________________________
# lst_s[5]=99->['d', 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm']
# lst_s+[None]*6->['d', 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm', None, None, None, None, None, None]
# lst_none[13]=2015->['d', 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm', None, None, None, 2015, None, None]
# lst_none[-6:-3]=list(range(100,104,2))->['d', 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm', 100, 102, 2015, None, None]
# lst_none[1:1]=[0,0,0,12]->['d', 0, 0, 0, 12, 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm', 100, 102, 2015, None, None]
# del lst_none[-2:]->['d', 0, 0, 0, 12, 'e', 'f', 'g', 'h', 99, 'j', 'k', 'l', 'm', 100, 102, 2015]

# %%
#补充数据类型
#整数类型int
#可以表示正数、负数和零
n1=90
n2=-76
n3=0
print(n1,type(n1))
print(n2,type(n2))
print(n3,type(n3))
#整数可以表示为二进制、十进制、八进制、十六进制
print('十进制',118)
print('二进制',0b101001111) #二进制以0b开头
print('八进制',0o176)  #八进制以0o开头
print('十六进制',0x1EAF)  #十六进制0x开头

#浮点类型:浮点数=整数＋小数 float
a=3.14159
print(a,type(a))

n1=1.1
n2=2.2
print(n1+n2)

from decimal import Decimal


#布尔类型 用来表示真或假的值 bool
f1=True
f2=False
print('f1',type(f1))
print('f2',type(f2))


#布尔值可以转成整数运算
print(f1+1)
print(f2+1)


#字符串类型（又被称为不可变的字符序列,用单引号，双引号，三引号来定义） str
str1='我爱帅哥'
str2="我爱帅哥"
str3="""我爱
帅哥"""
print(str1,type(str1))


#数据类型转换 #str(),int(),float()
name='张三'
age=20
print(name,type(name))
print(age,type(age))
print('我叫'+name+'，今年'+str(age)+'岁')#将int类型转换成str
#str(),int(),float()
s1='128'
f1=98.7
s2='78.77'
ff=True
s3='hello'
print(type(s1),type(f1),type(s2),type(ff),type(s3))
print(int(s1)) #将str转化为int类型，字符串为数字串
print(int(f1),type(int(f1))) #float转化为int类型，去尾法
#print(int(s2),type(s2))  报错原因：字符串为小数串
print(int(ff),type(int(ff)))


print()
s1='128.98'
s2='76'
ff=True
s3='hello'
print(type(s1),type(s2),type(ff),type(s3))
print(float(s1),type(float(s1)))
print(float(s2),type(float(s2)))
print(float(ff),type(float(ff)))
#print(float(s3),type(float(s3))) #不能为非数字串

# %%
#tuple
tuple_1=2,3,5,
print("tuple_1=2,3,5,->{}".format(tuple_1))
print("3*(20*3,)->{}".format(3*(20*3,)))
print("tuple((5,8,9))->{}".format(tuple((5,8,9)))) #用()
print("tuple([5,8,9])->{}".format(tuple([5,8,9]))) #用[]

#元组知识点
'''
元组是一个不可变序列
'''
lst=[10,20,45]
print(id(lst))
lst.append(60)
print(id(lst)) #不可变序列：字符串，元组     没有增删改操作

s='hello'
print(id(s))
s=s+'world'
print(id(s))
print(s) #可变序列：列表，字典     可以对序列执行增删改操作，对象地址不发生更改
#元组：t=('Python','hello',90)
#创建元组的方式
t=('Python','hello',90)
print(t)
print(type(t))  #使用t=（'')或t=''
t1=tuple(('Python','hello',90))
print(t1)
print(type(t1)) #使用内置函数tuple（）
t='python'
print(t)
print(type(t)) #类型为str
t = 'python',
print(t)
print(type(t))  #类型为tupel
#如果元组中只有一个元素，那么逗号不能省略

#空元组的创建方式
t4=()
t5=tuple()
print('空元组',t4,t5)

#
t=(10,[20,30],9)
print(t)
print(type(t))
print(t[0],type([0]),id(t[0]))
print(t[1],type([0]),id(t[1]))
print(t[2],type([0]),id(t[2]))
#t[1]=100  报错原因：元组不允许修改
'''由于t[2]为可变序列列表，因此可以通过修改元组中的可变元素'''

#元组的遍历
t=['Python','world',98]
print(t[0],t[1],t[2])
for item in t:
    print(item)
# Out:
# tuple_1=2,3,5,->(2, 3, 5)
# 3*(20*3,)->(60, 60, 60)
# tuple((5,8,9))->(5, 8, 9)
# tuple([5,8,9])->(5, 8, 9)

# %%
#字典
import random
items=[(0,[i for i in range(5)]),(1,[random.sample(list(range(100,200,1)),3)]),(2,'python')] #[i for i in range(5)] 为列表推导式 list comprehension/derivation
print("items->{}".format(items))
dic=dict(items)
print("dic=dict(items)->{}".format(dic))
print("dic[1]->{}".format(dic[1]))

#知识点
#{}定义字典，可变无序序列，以键值对的方式存储，而列表单独存储，键：值，元素与元素之间用逗号分隔
#字典的创建
scores={'龚俊':1129,'五黑框':'Be'}
print(scores)
print(type(scores)) #使用{}
idol=dict(name='龚俊',age='28')
print(idol) #使用内置函数dict=
scores=()
idol=dict()
print(scores,idol) #创建空字典
# Out:
# items->[(0, [0, 1, 2, 3, 4]), (1, [[124, 166, 157]]), (2, 'python')]
# dic=dict(items)->{0: [0, 1, 2, 3, 4], 1: [[124, 166, 157]], 2: 'python'}
# dic[1]->[[124, 166, 157]]

# %%
#字典的基本操作
print("len(dic)->{}".format(len(dic)))
dic[3]=(random.random(),random.uniform(200,300))
print("dic[3]=(random.random(),random.uniform(200,300))->{}".format(dic))
del dic[1]
print("del dic[1]->{}".format(dic))
print("3 in dic->{}".format(3 in dic))
print("5 in dic->{}".format(5 in dic))
print("dic.keys()->{}".format(dic.keys())) 
print("dic.values()->{}".format(dic.values()))
print("dic.items()->{}".format(dic.items()))
print("_"*50)
print("list(dic.keys())->{}".format(list(dic.keys())))
# Out:
# len(dic)->3
# dic[3]=(random.random(),random.uniform(200,300))->{0: [0, 1, 2, 3, 4], 1: [[124, 166, 157]], 2: 'python', 3: (0.3583999964735495, 262.7292754540373)}
# del dic[1]->{0: [0, 1, 2, 3, 4], 2: 'python', 3: (0.3583999964735495, 262.7292754540373)}
# 3 in dic->True
# 5 in dic->False
# dic.keys()->dict_keys([0, 2, 3])
# dic.values()->dict_values([[0, 1, 2, 3, 4], 'python', (0.3583999964735495, 262.7292754540373)])
# dic.items()->dict_items([(0, [0, 1, 2, 3, 4]), (2, 'python'), (3, (0.3583999964735495, 262.7292754540373))])
# __________________________________________________
# list(dic.keys())->[0, 2, 3]

# %%
for k,v in enumerate(dic.items()): 
    print(k,v)
    #for 循环知识点在后文
# Out:
# 0 (0, [0, 1, 2, 3, 4])
# 1 (2, 'python')
# 2 (3, (0.3583999964735495, 262.7292754540373))

# %%
#字典的方法
lst_A=list(range(6,20,3))
lst_B=list(range(100,150,15))
print("lst_A={},lst_B={}".format(lst_A,lst_B))
dic_2={0:lst_A,1:lst_B}
print("dic_2={}".format(dic_2))
print("_"*50)
dic_assignment=dic_2
print("dic_assignment={}".format(dic_assignment))
dic_2.clear()
print("dic_2.clear()->{}".format(dic_2))
print("dic_assignment={}".format(dic_assignment))
dic_2[5]=list(range(1,9,2))
print("dic_2[5]=list(range(1,9,2))->{}".format(dic_2))
dic_copy=dic_2.copy()
print("dic_copy=dic_2.copy()->{}".format(dic_copy))
dic_2[8]=[5,7]
print("dic_2[8]=[5,7]->{}".format(dic_2))
print("dic_copy={}".format(dic_copy))
dic_copy[5].remove(5)
print("dic_copy[5].remove(5)->{}".format(dic_copy))
dic_copy.setdefault(6,[77,99]) #返回指定键的值，如果不存在该键，则字典增加新的键/值对
print("dic_copy.setdefault(6,[77,99])->{}".format(dic_copy))
dic_2.pop(5) #移除指定键/值，并返回该值
print("dic_2.pop(5)->{}".format(dic_2))
dic_update={8:[5,7,6,3,2],9:[3,2,33,55,66]}
print("dic_update={}".format(dic_update))
dic_2.update(dic_update) #更新字典
print("dic_2.update(dic_update->{}".format(dic_2))
print("dic_2.get(9)->{}".format(dic_2.get(9)))
dic_2.popitem() #随即弹出一对键/值，并在该字典中移除
print("dic_2.popitem()->{}".format(dic_2))

dic_3={}.fromkeys([0,1,2,3,4,'A']) #给定键，建立值为空的字典
print("dic_3={}"+".fromkeys([0,1,2,3,4,'A'])->{}".format(dic_3)) #找下escape characters 脱字符


#知识点
#字典中的常见操作
#获取字典中的元素
scores={'龚俊':1129,'五黑框':'Be','双宋':'BE'}
print(scores['龚俊']) #[]
print(scores.get('龚俊'))
#print(scores['龚俊'])  不存在，报错
print(scores.get('帅哥')) #显示None,不会报错
print(scores.get('帅哥',99)) #99是在查找不存在的'帅哥'时，给出的默认值

scores={'龚俊':1129,'五黑框':'Be','双宋':'BE'}
print('龚俊' in scores)
print('龚俊' not in scores) #字典的存在性问题判断

del scores['龚俊']
print(scores) #删除指定的键值对
#scores.clear() #清空字典
print(scores)
scores['帅哥']=20
print(scores) #增加键值对
scores['帅哥']='李子维'
print(scores) #修改元素

scores={'龚俊':1129,'五黑框':'Be','双宋':'BE'}
lo=scores.keys()
print(lo) #获取所有键
print(type(lo))
print(list(lo)) #将所有键转为列表
ve=scores.values()
print(ve)
print(type(ve)) #获取所有值

love=scores.items()
print(love)
print(list(love)) #转换后的列表元素由元组组成

#字典元素的遍历
for item in scores:
    print(item,scores[item])

dict={'name':'魏化俊','name':'许光汉'}
print(dict) #键不允许重复，重复显示最后
dict={'actor':'韩国','name':'许光汉'}
print(dict) #value可以重复
# Out:
# lst_A=[6, 9, 12, 15, 18],lst_B=[100, 115, 130, 145]
# dic_2={0: [6, 9, 12, 15, 18], 1: [100, 115, 130, 145]}
# __________________________________________________
# dic_assignment={0: [6, 9, 12, 15, 18], 1: [100, 115, 130, 145]}
# dic_2.clear()->{}
# dic_assignment={}
# dic_2[5]=list(range(1,9,2))->{5: [1, 3, 5, 7]}
# dic_copy=dic_2.copy()->{5: [1, 3, 5, 7]}
# dic_2[8]=[5,7]->{5: [1, 3, 5, 7], 8: [5, 7]}
# dic_copy={5: [1, 3, 5, 7]}
# dic_copy[5].remove(5)->{5: [1, 3, 7]}
# dic_copy.setdefault(6,[77,99])->{5: [1, 3, 7], 6: [77, 99]}
# dic_2.pop(5)->{8: [5, 7]}
# dic_update={8: [5, 7, 6, 3, 2], 9: [3, 2, 33, 55, 66]}
# dic_2.update(dic_update->{8: [5, 7, 6, 3, 2], 9: [3, 2, 33, 55, 66]}
# dic_2.get(9)->[3, 2, 33, 55, 66]
# dic_2.popitem()->{8: [5, 7, 6, 3, 2]}
# dic_3={}.fromkeys([0,1,2,3,4,'A'])->{0: None, 1: None, 2: None, 3: None, 4: None, 'A': None}

# %%
#string-基础
lst_s_3=list("Hello Python!")
print("lst_s_3=list(\"Hello Python!\")->{}".format(lst_s_3)) #"\" escape character
print("\"Hellow\"+\" Python!\"->{}".format("Hellow"+" Python!"))
print("\"+\".join(str(123456))->{}".format("+".join(str(123456))))
print("len(\"Hellow Python!\")->{}".format(len("Hellow Python!")))
coordinates="120.132007,30.300508,9.7"
print("coordinates.split(\",\")->{}".format(coordinates.split(",")))
print("eval(coordinates)->{}".format(eval(coordinates))) #通常用eval()方法将字符串，转换为对应数值形式；
print("\"Hello Python!\".lower()->{}".format("Hello Python!".lower()))
print("\"Hello Python!\".upper()->{}".format("Hello Python!".upper()))
print("\"Hello Python!\"[6:]->{}".format("Hello Python!"[6:]))
print("\"    Hello Python!    \".strip()->{}".format("    Hello Python!    ".strip()))
print("\"Hello Python!\".replace(\"Python\",\"Grasshopper\")->{}".format("Hello Python!".replace("Python","Grasshopper")))
hello_lst=list("Hello Python!")
hello_lst.sort()
print("hello_lst.sort()>{}".format(hello_lst))
print("\"Hello Python!\".find(\"Py\")->{}".format("Hello Python!".find("Py")))

##字符串为不可变序列

#字符串的驻留机制
a='python'
b="python"
c='''python'''
print(a,id(a))
print(b,id(b))
print(c,id(c)) #a,b,c为同一份字符串，不开辟新空间
'''驻留条件
1、字符串的长度为0或1时
2、符合标识符的字符串
3、驻留只在编译时产生，不在运行时
4、[-5,256]之间的整数数字
5、sys中的intern方法强制2个字符串指向同一个对象'''

#字符串的查询操作 index() rindex() find() rfind()
s='hello,hello'
print(s.index('lo')) #3
print(s.rindex('lo')) #9
print(s.find('lo')) #3
print(s.rfind('lo')) #9

#print(s.index('k')) 因不存在而报错
print(s.find('k'))
#print(s.rindex('k')) 因不存在而报错
print(s.rfind('k'))

#字符串的大小写转化操作 upper() lower() swapcase()
s='hello,junjun'
a=s.upper()
print(a,id(a))
print(s,id(s)) #产生一个新的字符串对象
b=s.lower()
print(s.lower(),id(s.lower()))
print(s,id(s)) #转换之后会产生新的字符串对象
print(b==s)
print(b is s) #F
s2='hello,Python'
print(s2.swapcase()) #大小写变化
print(s2.title()) #单个单词的首字母大小写变化

#字符串的常用操作——对齐 center() ljust() rjust() zfill()
s='hello,Python'
print(s.center(20,'*')) #字符串长度为12，总宽为20，字符串在总宽中居中,'*'为填充空格符
print(s.center(20)) #默认空格
print(s.ljust(20,'*')) #左对齐
print(s.ljust(10,'*')) #总宽小于字符串长度，返回正常格式

print(s.rjust(20,'*')) #右对齐
print(s.rjust(20)) #默认空格
print(s.rjust(10,'*')) #返回

print(s.zfill(20)) #只有一个参数，用’0‘填充
print(s.zfill(10)) #返回
print('-8910'.zfill(8)) #右对齐

#字符串的劈分操作
s='hello world python'
lst=s.split()
print(lst) #从左劈分，默认劈分字符为空格字符串，返回值为list
s1='hello丨world丨python'
lst=s1.split()
print(lst) #一个字符串
print(s1.split(sep='丨')) #通过参数sep指定劈分字符串
print(s1.split(sep='丨',maxsplit=1)) #使用maxsplit限次劈分
print(s.rsplit()) #从右劈分
print(s1.rsplit(sep='丨'))
print(s1.rsplit(sep='丨',maxsplit=1)) #difference

#字符串的判断方法
s='hello,python'
print('1.',s.isidentifier()) #不是合法标识符，逗号不属于
print('2.','hello'.isidentifier())
print('3.','张三'.isidentifier()) #T
print('3.','张三_123'.isidentifier()) #T

#字符串是否全部由空白字符串组成（回车、换行、水平制表符）
print('5.','\t'.isspace()) #T
#是否全部由字母组成
print('abc'.isalpha()) #T
print('a,b,c'.isalpha()) #F
print('魏化俊'.isalpha())
print('魏化俊1'.isalpha()) #F
print('123'.isalpha()) #F
#是否全部由十进制数字组成
print('123'.isdecimal()) #T
print('123四'.isdecimal()) #F
print('Ⅰ'.isdecimal()) #F
#数字
print('123'.isnumeric()) #T
print('123四'.isnumeric()) #T
print('Ⅰ'.isnumeric()) #F
#字母和数字
print('abcd'.isalnum())
print('李子维'.isalnum()) #T
print('love!@'.isalnum()) #F

#字符串替换
s='ve,lo'
print(s.replace('lo','love'))
s1='lo,ve,ve'
print(s1.replace('ve','love',2))
#字符串合并
lst=['lo','ve','love']
print('丨'.join(lst))
print(''.join(lst)) #列表

t=('lo','ve','love')
print('丨'.join(t)) #元组
print('*'.join('love')) #love被当作字符串操作

#字符串的比较
print('lo'>'love') #F
print('lo'>'hate') #T
#比较原理
print(ord('a'),ord('b'))  #a=97,b=98
print(chr(97),chr(98))
print(ord('龚'))
print(chr(40858)) #相反操作
'''==与is的区别
==比较value，is比较id（内存地址）是否相同 '''
a=b='龚俊'
c='龚俊'
print(a==b)
print(b==c)
print(a is b)
print(a is c)
print(id(a),id(b),id(c)) #the same

#字符串的切片操作，产生新对象 [start:end:step]
s='veslouslove'
s1=s[:2] #未指定起始位置，从0开始
print(s1)
s2=s[7:] #未指定结束位置，直到结尾
print(s2)
s3='is'
newstr=s1+s3+s2
print(newstr)
print(id(s1))
print(id(s2))
print(id(s3))
print(id(s))
print(id(str)) #五个新的字符串
print(s[7:11:1]) #从7-11不包括7
print(s[::2]) #无指定开始和结尾，索引间隔为2
print(s[::-1]) #未指定，倒序
print(s[-4::1]) #倒数正计
# Out:
# lst_s_3=list("Hello Python!")->['H', 'e', 'l', 'l', 'o', ' ', 'P', 'y', 't', 'h', 'o', 'n', '!']
# "Hellow"+" Python!"->Hellow Python!
# "+".join(str(123456))->1+2+3+4+5+6
# len("Hellow Python!")->14
# coordinates.split(",")->['120.132007', '30.300508', '9.7']
# eval(coordinates)->(120.132007, 30.300508, 9.7)
# "Hello Python!".lower()->hello python!
# "Hello Python!".upper()->HELLO PYTHON!
# "Hello Python!"[6:]->Python!
# "    Hello Python!    ".strip()->Hello Python!
# "Hello Python!".replace("Python","Grasshopper")->Hello Grasshopper!
# hello_lst.sort()>[' ', '!', 'H', 'P', 'e', 'h', 'l', 'l', 'n', 'o', 'o', 't', 'y']
# "Hello Python!".find("Py")->6

# %%
#字符串格式化
format_str="Hello,%s and %s!"
values=("Python","Grasshopper")
new_str=format_str % values
print("new_str=format_str % values->{}".format(new_str))

format_str_2="Pi with three decimals:%.3f,and enter a value with percent sign:%.2f %%" #如果字符串里包含实际的%，则通过%%即两个百分号进行转义

from math import pi
new_str_2=format_str_2 % (pi,3.1415926)
print("new_str_2=format_str_2 % (pi,3.1415926)->{}".format(new_str_2))

#知识点
#字符串的格式化:按一定形式输出的字符串

#%占位 %s:str %d:%i:int %f:float
name='lo'
age='love'
print('ve是%s没说出口的%s' % (name,age))

#{}
print('ve是{0}没说出口的{1}'.format(name,age))

#f格式化
print(f've是{name}没说出口的{age}')

print('%d' % 99)
print('%10d' % 99) #10表示宽度
print('hellohello')
print('%.3f' % 3.1415926) #.3为精度，保留三位小数
print('%10.3f' % 3.1415926) #同时调整精度和宽度
print('{}'.format(3.1415926))
print('{0:.3}'.format(3.1415926)) #.3表示只有三位数
print('{0:.3f}'.format(3.1415926)) #.3f表示三位小数
print('{:10.3f}'.format(3.1415926)) #同时设置宽度和精度

#字符串的编码转换
s='纸媒竟已没落至此'
#编码
print(s.encode(encoding='GBK')) #在GBK中，一个中文占两个字节
print(s.encode(encoding='UTF-8')) #在UTF-8中，一个中文占三个字节
#解码 byte代表二进制数据（字节类型的数据)
byte=s.encode(encoding='GBK') #编码
print(byte.decode(encoding='GBK')) #解码
#print(byte.decode(encoding='UTF-8'))  解码失败，编码解码方法不同
# Out:
# new_str=format_str % values->Hello,Python and Grasshopper!
# new_str_2=format_str_2 % (pi,3.1415926)->Pi with three decimals:3.142,and enter a value with percent sign:3.14 %

# %%
format_str_3="%10f,%10.2f,%.2f,%.5s,%.*s,%d,%x,%f"
new_str_3=format_str_3%(pi,pi,pi,"Hello Python!",5,"Hello Python!",52,52,pi)
print("{}".format(new_str_3))
# Out:
#   3.141593,      3.14,3.14,Hello,Hello,52,34,3.141593

# %%
from string import Template
s_template_1=Template("$x,glorious,$x!")
s_1=s_template_1.substitute(x="Python")
print("s_1=s_template_1.substitute(x=\"Python\")->{}".format(s_1))
s_template_2=Template("${x}thon is amazing!")
s_2=s_template_2.substitute(x="py")
print("s_2=s_template_2.substitute(x=\"py\")->{}".format(s_2))
s_template_3=Template("$x and $y are both amazing!")
substitute_dict=dict([('x','Python'),('y','Grasshopper')])
print("substitute_dict={}".format(substitute_dict))
s_3=s_template_3.substitute(substitute_dict)
print("s_3=s_template_3.substitute(substitute_dict)->{}".format(s_3))
# Out:
# s_1=s_template_1.substitute(x="Python")->Python,glorious,Python!
# s_2=s_template_2.substitute(x="py")->python is amazing!
# substitute_dict={'x': 'Python', 'y': 'Grasshopper'}
# s_3=s_template_3.substitute(substitute_dict)->Python and Grasshopper are both amazing!

# %%
#string-re(正则表达式)
#字符匹配-模式语法
import re
pattern_1='Python'
text="Hello Python!"
print("re.findall(pattern_1,text)->{}".format(re.findall(pattern_1,text)))
pattern_2='python'
print("re.findall(pattern_2,text)->{}".format(re.findall(pattern_2,text)))

print("re.findall('.ython','Hello Python!')->{}".format(re.findall('.ython','Hello Python!')))
print("re.findall('.ython','Hello gython!')->{}".format(re.findall('.ython','Hello gython!')))
print("re.findall('.ython','Hello gPython!')->{}".format(re.findall('.ython','Hello gPython!')))
print("re.findall('.ython','Hello Pthon!')->{}".format(re.findall('.ython','Hello Pthon!')))

#* + ？ {m,n}与r’string’
print("re.findall(r'w?cadesign\.cn,w+\.cadesign\.cn','cadesign.cn,www.cadesign.cn')->{}".format(re.findall(r'w?cadesign\.cn,w+\.cadesign\.cn','cadesign.cn,www.cadesign.cn')))
print("re.findall(r'w{2}"+"\.cadesign\.cn','www.cadesign.cn')->{}".format(re.findall(r'w{2}\.cadesign\.cn','www.cadesign.cn')))
print("re.findall(r'w{1,3}"+"\.cadesign\.cn','www.cadesign.cn')->{}".format(re.findall(r'w{1,3}\.cadesign\.cn','www.cadesign.cn')))

#[] (^)
print("re.findall('[Py]*thon!','Hello Python!')->{}".format(re.findall('[Py]*thon!','Hello Python!')))
print("re.findall('[Py]*thon!','Hello Pthon!')->{}".format(re.findall('[Py]*thon!','Hello Pthon!')))
print("re.findall('[Py]*thon!','Hello ython!')->{}".format(re.findall('[Py]*thon!','Hello ython!')))
print("re.findall('[Py]*thon!','Hello ython!')->{}".format(re.findall('[Py]*thon!','Hello thon!')))

#(|)管道符号
print("re.findall('python|grasshopper','python')->{}".format(re.findall('python|grasshopper','python')))
print("re.findall('python|grasshopper','grasshopper')->{}".format(re.findall('python|grasshopper','grasshopper')))
print("re.findall('python|grasshopper','grasshopper and python')->{}".format(re.findall('python|grasshopper','grasshopper and python')))

#\d \D
print("re.findall('\d','number=10')->{}".format(re.findall('\d','number=10')))
print("re.findall('\D','number=10')->{}".format(re.findall('\D','number=10')))
print("re.findall('[^0-9]','number=10')->{}".format(re.findall('[^0-9]','number=10')))

#re模块的方法
print("re.findall('[a-z]','python')->{}".format(re.findall('[a-z]','python-3.0')))
print("re.search('[a-z]+','python')->{}".format(re.search('[a-z]+','python')))
if re.search('[a-z]+','python'):
    print("re.search('[a-z]+','python')->found it!")
print("re.split(',','Hello,,,,,,Python!')->{}".format(re.split(',','Hello,,,,,,Python!')))
print("re.sub('Python','Grasshopper','Hello Python!')->{}".format(re.sub('Python','Grasshopper','Hello Python!')))

pattern_compile=re.compile('Python')
print("pattern_compile.findall('Hello,,,,,,Python!')->{}".format(pattern_compile.findall('Hello,,,,,,Python!')))

if re.match('p','python'):
    print("re.match('p','python')->found it!")
    
print("\'python\'.find(\'python\')->{}".format('python'.find('python')))
print("\'python\'.find(\'thon\')->{}".format('python'.find('thon')))
print("\'python\'.find(\'a\')->{}".format('python'.find('a')))
print("\'p\' in \'python\'->{}".format('p' in 'python'))

print("\'Hello,,,,,,Python!\'.split(',')->{}".format( 'Hello,,,,,,Python!'.split(',')))
print("\'Hello Python!\'.replace(\'Python\',\'Grasshopper\')->{}".format( 'Hello Python!'.replace('Python','Grasshopper')))
# Out:
# re.findall(pattern_1,text)->['Python']
# re.findall(pattern_2,text)->[]
# re.findall('.ython','Hello Python!')->['Python']
# re.findall('.ython','Hello gython!')->['gython']
# re.findall('.ython','Hello gPython!')->['Python']
# re.findall('.ython','Hello Pthon!')->[]
# re.findall(r'w?cadesign\.cn,w+\.cadesign\.cn','cadesign.cn,www.cadesign.cn')->['cadesign.cn,www.cadesign.cn']
# re.findall(r'w{2}\.cadesign\.cn','www.cadesign.cn')->['ww.cadesign.cn']
# re.findall(r'w{1,3}\.cadesign\.cn','www.cadesign.cn')->['www.cadesign.cn']
# re.findall('[Py]*thon!','Hello Python!')->['Python!']
# re.findall('[Py]*thon!','Hello Pthon!')->['Pthon!']
# re.findall('[Py]*thon!','Hello ython!')->['ython!']
# re.findall('[Py]*thon!','Hello ython!')->['thon!']
# re.findall('python|grasshopper','python')->['python']
# re.findall('python|grasshopper','grasshopper')->['grasshopper']
# re.findall('python|grasshopper','grasshopper and python')->['grasshopper', 'python']
# re.findall('\d','number=10')->['1', '0']
# re.findall('\D','number=10')->['n', 'u', 'm', 'b', 'e', 'r', '=']
# re.findall('[^0-9]','number=10')->['n', 'u', 'm', 'b', 'e', 'r', '=']
# re.findall('[a-z]','python')->['p', 'y', 't', 'h', 'o', 'n']
# re.search('[a-z]+','python')-><re.Match object; span=(0, 6), match='python'>
# re.search('[a-z]+','python')->found it!
# re.split(',','Hello,,,,,,Python!')->['Hello', '', '', '', '', '', 'Python!']
# re.sub('Python','Grasshopper','Hello Python!')->Hello Grasshopper!
# pattern_compile.findall('Hello,,,,,,Python!')->['Python']
# re.match('p','python')->found it!
# 'python'.find('python')->0
# 'python'.find('thon')->2
# 'python'.find('a')->-1
# 'p' in 'python'->True

# %%
#匹配对象和组
match_1=re.match(r'www\.(.*)\..{3}','www.python.org')
print("match_1.gourp(1)->{}".format(match_1.group(1)))
print("match_1.start(1)->{}".format(match_1.start(1)))
print("match_1.end(1)->{}".format(match_1.end(1)))
print("match_1.span(1)->{}".format(match_1.span(1)))
match_2=re.match(r'www\.(.*)\.(.{3})','www.python.org')
print("match_2.group(1)->{}".format(match_2.group(1)))
print("match_2.group(2)->{}".format(match_2.group(2)))
# Out:
# match_1.gourp(1)->python
# match_1.start(1)->4
# match_1.end(1)->10
# match_1.span(1)->(4, 10)
# match_2.group(1)->python
# match_2.group(2)->org

# %%
#循环语句
#for循环
lst_1=list(range(29,37,2))
print("lst_1={}".format(lst_1))
print("_"*50)
print("for i in lst_1:")
for i in lst_1:
    print(i)
print("for i in range(len(lst_1)):")
for i in range(len(lst_1)):
    print("idx={},val={}".format(i,lst_1[i]))
print("+"*50)   
dic_4=dict(a=2,b=3,c=6,d=0)
print("dic_4={}".format(dic_4))
print("_"*50)
print("for k in dic_4:")
for k in dic_4:
    print(k)
print("for k,v in dic_4.items():")
for k,v in dic_4.items():
    print("key={},val={}".format(k,v))

#while循环
x=1
while x<=100:
    print("x={}".format(x))
    x+=10 #增量赋值; x*=2   
    
x=1
while x<=100:
    print("x={}".format(x))
    x+=10 
    if x>=50:break    
    
import sys
print("sys.maxsize={}".format(sys.maxsize))
for i in range(sys.maxsize):
    print("i={}".format(i))  #?
    i+=10
    if i>=30:break

#嵌套循环
#输出一个三行四列的矩形
for i in range(1,4): #行表，执行三次，一次一行
    for j in range(1,5):
        print('*',end='\t') #不换行输出
    print() #打行
#内层控制行数，外层控制个数

#打印一个直角三角形
for i in range(1,10): #行数
    for j in range(1,i+1):
        print('*',end='')
    print()

#打印一个乘法口诀表
for i in range(1,10):
    for j in range(1,i+1):
        print(i,'*',j,'=',i*j,end='\t')
    print()

# %%
#并行迭代
lst_a=[0,1,2,3]
lst_b=['point_a','point_b','point_c','point_d']
zip_lst=zip(lst_a,lst_b) #The zip() function takes iterables (can be zero or more), aggregates them in a tuple, and returns it.
print("zip_lst=zip(lst_a,lst_b)->{}".format(zip_lst))
print("dict(zip_lst)->{}".format(dict(zip_lst)))

zip_lst=zip(lst_a,lst_b) #迭代对象临时存储，读取完后为空
for a,b in zip_lst:
    print(a,b)
    
zip_lst=zip(lst_a,lst_b)
a,b=zip(*zip_lst)
print("a={},b={}".format(a,b))

#编号迭代
lst_c=['point_a','point_b','point_c','point_d']
dic_4={}
for idx,value in enumerate(lst_c):
    dic_4[idx]=value
print("dic_4={}".format(dic_4))
print("dict((i,v) for i,v in enumerate(lst_c))->{}".format(dict((i,v) for i,v in enumerate(lst_c)))) #list comprehension
print("_"*50)
for i,(a,b) in enumerate(zip(lst_a,lst_b)):
    print('%d:%s,%s'%(i,a,b))

#列表推导式
print("[x*x for x in range(3,37,5) if x%2==0]->{}".format([x*x for x in range(3,37,5) if x%2==0]))
print("[(x,y) for x in range(3)for y in range(2)]->{}".format([(x,y) for x in range(3)for y in range(2)]))
print("[(x,y) for x,y in zip(range(3),range(2))]->{}".format([(x,y) for x,y in zip(range(3),range(2))]))
nested_list=[[a for a in range(1,10,3)],2,3,[b for b in range(60,100,7)],[[c for c in range(1000,2000,120)],3,9]]
print("[[a for a in range(1,10,3)],2,3,[b for b in range(60,100,7)],[[c for c in range(1000,2000,120)],3,9]]->{}".format(nested_list)) #嵌套列表推导式

flatten_lst=lambda lst: [m for n_lst in lst for m in flatten_lst(n_lst)] if type(lst) is list else [lst] #展平列表常用，可以放置到单独的.py文件中调用。lambda函数后文阐述
print("flatten_lst(nested_list)->{}".format(flatten_lst(nested_list)))
# Out:
# zip_lst=zip(lst_a,lst_b)-><zip object at 0x000001D69C7D4D00>
# dict(zip_lst)->{0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# 0 point_a
# 1 point_b
# 2 point_c
# 3 point_d
# a=(0, 1, 2, 3),b=('point_a', 'point_b', 'point_c', 'point_d')
# dic_4={0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# dict((i,v) for i,v in enumerate(lst_c))->{0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# __________________________________________________
# 0:0,point_a
# 1:1,point_b
# 2:2,point_c
# 3:3,point_d
# [x*x for x in range(3,37,5) if x%2==0]->[64, 324, 784]
# [(x,y) for x in range(3)for y in range(2)]->[(0, 0), (0, 1), (1, 0), (1, 1), (2, 0), (2, 1)]
# [(x,y) for x,y in zip(range(3),range(2))]->[(0, 0), (1, 1)]
# [[a for a in range(1,10,3)],2,3,[b for b in range(60,100,7)],[[c for c in range(1000,2000,120)],3,9]]->[[1, 4, 7], 2, 3, [60, 67, 74, 81, 88, 95], [[1000, 1120, 1240, 1360, 1480, 1600, 1720, 1840, 1960], 3, 9]]
# flatten_lst(nested_list)->[1, 4, 7, 2, 3, 60, 67, 74, 81, 88, 95, 1000, 1120, 1240, 1360, 1480, 1600, 1720, 1840, 1960, 3, 9]

# %%
#条件语句
'''
if expression:
    statements
elif expression:
    statements
elif expression:
    pass
...
else:
    statements'''
    
x=10
if x<0:
    print('It is negative.')
elif x==0:
    print('Equal to zero.')
elif 0<x<10:
    print('Positive but smaller than 10')
else:
    print('Positive and larger than or equal to 10.')
    
x=y=[3,6,9]
z=[3,6,9]
print("x==y->{}".format(x==y))
print("x is y->{}".format(x is y))
print("x==z->{}".format(x==z))
print("x is z->{}".format(x is z))
print("x is not y->{}".format(x is not y))
print("x is not z->{}".format(x is not z))
print("id_x:{};id_y:{};id_z:{}".format(id(x),id(y),id(z))) #Memory Location

del x[2]
print("x={},y={},z={} after del x[2]".format(x,y,z)) #相等运算符==与同一性运算符is

x=[3,6,9]
print("3 in x->{}".format(3 in x))
print("0 in x->{}".format(0 in x))
print("3 not in x->{}".format(3 not in x))
print("0 not in x->{}".format(0 not in x)) #成员资格运算符，in与not in

a,b,c=0,10,15
if c>a and c<b:
    print('a<c<b')
else: print('a<c<b kidding!!!') #布尔运算符
    
#顺序结构
print('程序开始')
print('1,把门打开')
print('2,把香蕉放进去')
print('3,把门关上')
print('程序结束')

#测试对象的布尔值
print(bool(False))
print(bool(0))
print(bool(0.0))
print(bool(None))
print(bool('')) #空字符串
print(bool([]))
print(bool(tuple()))

#选择结构
'''单分支结构
if 条件表达式:
   条件执行体'''
money=1000 #余额
s=int(input('请输入取款金额')) #取款金额
if money>=s:
   money=money-s
   print('取款成功，余额为：',money)

'''双分支结构
if 条件表达式:
   条件执行体1
else:
   条件执行体2'''
num=int(input('请输入一个整数'))
#条件判断
if num%2==0:
   print(num,'是偶数')
else:
   print(num,'是奇数')


'''多分支结构 多选一执行
if 条件表达式1:
   条件执行体1
elif 条件表达式:
     条件执行体2
elif 条件表达式:
     条件执行体N
#else：
     条件执行体N+1'''

score=int(input("请输入你的分数:"))
if score<=100 and score>90:
   print('A')
elif score>=80 and score<90:
   print('B')
elif score>=70 and score<80:
   print('C')
elif score>=60 and score<=60:
   print('D')
elif score<=60:
   print('F')
else:
   print('成绩有误')

#嵌套if
'''
if 条件表达式1：
   if 内层条件表达式：
      内层条件执行体1
   elif：
      内存条件执行体2
else：
      条件执行体'''

answer=input('您是会员么？y/n')
money=float(input('请输入你的购物金额'))
if answer=='y' :
   print('会员')
   if money>=200:
      print("打八折，付款金额为：",money*0.8)
   elif money>=100:
      print("打九折，付款金额为：",money*0.9)
   else:
      print('不打折')
else:
   if money>=200:
      print("付款金额为：",money*0.95)
   else:
      print('不打折')

'''流程控制相关知识点'''
#条件表达式
num_a=int(input('请输入一个整数'))
num_b=int(input('请输入第二个整数'))
if num_a>=num_b:
   print(num_a,"大于等于",num_b)
else:
   print(num_a,"小于",num_b)

print('使用条件表达式进行比较')
print((str(num_a),"大于等于",str(num_b)) if num_a>= num_b else str(num_a),"小于",str(num_b)) #判断为T，执行前面的执行体，F则执行后方

#Pass语句 搭建结构的占位符
answer=input('您是会员么？y/n')
if answer=='y':
   pass
else:
   pass

#循环结构
'''
while 条件表达式：
      条件循环体1'''

a=1
if a<10:
    print(a)
    a+=1

a=1
while a<10:
      print(a)
      a+=1 #if判断一次，while判断n+次

#累加和
'''while循环的四部循环法
1、初始化变量
2、条件判断
3、条件执行体
4、改变变量'''
sum=0
a=0
while a<5:
   sum+=a
   a+=1
   print('和为',sum)

#练习:
sum=0
a=1 #初始化变量
while a<101: #条件判断
   if a%2==0:
      sum+=a #条件执行体
   a+=1 #改变变量
print("1-100之间的偶数和",sum)

#for in 循环
for item in "python": #依次取出赋予item
   print(item)

for item in range(10):
   print(item)

#如果循环体中不需要自定义变量，可将自定义变量写为_,range()函数表示循环次数
for _ in range(5):
   print('velo')

'''循环中非正常结束程序'''

sum=0
for item in range(1,101):
    if item %2==0:
       sum+=item
print(sum)

#流程控制语句break 非正常结束程序
'''密码最多输入三次，正确就结束循环'''
for item in range(3):
    pwd=input("请输入密码")
    if pwd=='8888':
        print('密码正确')
        break #退出循环
    else:
        print('密码不正确')


a=0
while a<3:
    pwd=input('请输入密码：')
    if pwd=='8888':
        print('密码正确')

    else:
        print('密码不正确')

#流程控制语句continue
'''输入1-50间所有5的倍数 %5=0'''
for item in range(1,51):
    if item%5==0:
        print(item)

for item in range(1,51):
    if item%5!=0:
        continue
    print(item) #使用continue
    
'''二重循环中的break and continue用于控制本层循环'''
for i in range(5): #外层循环要执行五次
    for j in range(1,11):
        if j%2==0:
            break
        print(j) #输出结果为1 1 1 1 1，原因为break使得内层循环只执行一次

for i in range(5): #外层循环要执行五次
    for j in range(1,11):
        if j%2==0:
            #break
            continue
        print(j,end='\t')
    print() 


#else语句
'''if else  if不成立执行else
while else  for else 没有遇到break 执行break'''
for item in range(3):
    pwd=input("请输入密码")
    if pwd=='8888':
        print('密码正确')
        break
    else:
        print('密码不正确')
else:
    print('对不起，三次密码均输入错误，账号已锁定')

a=0
while a<3:
    pwd=input('请输入密码')
    if pwd=='8888':
        print('密码正确')
        break
    else:
        print('密码错误')
    a+=1  #改变变量
else:
    print('该账户已锁定')
# Out:
# Positive and larger than or equal to 10.
# x==y->True
# x is y->True
# x==z->True
# x is z->False
# x is not y->False
# x is not z->True
# id_x:2021261592192;id_y:2021261592192;id_z:2021261594048
# x=[3, 6],y=[3, 6],z=[3, 6, 9] after del x[2]
# 3 in x->True
# 0 in x->False
# 3 not in x->False
# 0 not in x->True
# a<c<b kidding!!!
# 程序开始
# 1,把门打开
# 2,把香蕉放进去
# 3,把门关上
# 程序结束
# False
# False
# False
# False
# False
# False
# False

# %%
#函数
'''函数的定义
def function(arguments):
    statement
    ...
    return values'''


def simple_func(x,y):
    z=pow(x,2)+y
    return z
print("simple_func(3,7)->{}".format(simple_func(3,7)))
print("simple_func(7,3)->{}".format(simple_func(7,3)))
print("simple_func(y=7,x=3)->{}".format(simple_func(y=7,x=3)))

'''定义斐波那契数列函数
F_0=0
F_1=1
F_n=F_{n-1}+ F_{n-2}（n≧2）'''


'''知识点'''
#函数定义与调用，参数传递
def calc(a,b):  #a,b成为形式参数，简称形参，形参位置在函数的定义处
    c=a+b
    return c
result=calc(10,20) #10，20称为实际参数，简称实参，位置在函数调用处
print(result) #位置实参
res=calc(b=10,a=20) #等号左侧变量名称为关键字参数，按照赋值不按照顺序
print(res)

def fun(arg1,arg2):
    print('arg1=',arg1)
    print('arg2=',arg2)
    arg1=100
    arg2.append(10)
    print('arg1=', arg1)
    print('arg2=', arg2)

n1=11
n2=[22,33,44]
print('n1=',n1)
'''在函数调用过程中进行参数传递，
如果是一个不可变的对象，在函数体内的修改，不会影响实参的值（arg1=100)
如果可变，则会影响(arg2.append(100）'''
print('n2=',n2)
fun(n1,n2) #将位置传参，arg1,arg2是函数定义的形参，n1,n2是函数调用处的实参 实参可以不等于形参名称
print('n1=',n1) #n1并没有改变
print('n2=',n2)

#函数返回多个值时，结果为元组
print(bool(0))
print(bool(1))
print(bool(4)) #非0布尔值为T
def fun(num):
    odd=[] #奇数
    even=[] #偶数
    for i in num:
        if i%2:
            odd.append(i)
        else:
            even.append(i)
    return odd,even


'''函数的调用'''

lst=[10,20,33,44,55,64,76,77] #函数的调用
print(fun(lst))
'''如果函数没有返回值[函数调用完毕之后，不用给调用处提供数据]，return可以省略
函数的返回值，如果是一个，直接返回类型
如果是多个，返回元组'''
def fun1():
    print('hello')
fun1()

def fun2():
    return'hello'
res=fun2()
print(res)

def fun3():
    return'hello','world'
print(fun3())
s=fun3()
print(s)
#函数在定义时，是否需要返回值视情况而定

def fun(a,b=10): #b为默认值参数
    print(a,b)

#函数的调用
fun(100)
fun(20,30)

print('hello')
print('world') #默认换行
print('hello',end='\t') #不换行
print('world')

#函数的参数定义
def fun(*args): #函数定义时的可变的位置参数（按顺序传）
    print(args)
#定义函数时，可能无法事先确定传递的位置实参的个数时，使用*定义可变的位置参数，结果为元组

fun(10)
fun(10,30)
fun(10,4,5,6)

def fun1(**args): #个数可变的关键字形参
    print(args)

fun1(a=10)
fun1(a=20,b=30,c=6)
#定义函数时，可能无法事先确定传递的关键字实参的个数时，使用**定义个数可变的关键字参数，结果为字典

print('hello','world','love') #所以一个print函数可以定义多个参数

'''def fun2(*args,*a):
    pass
    报错原因：可变的位置参数只能是一个'''
'''def fun2(**args,**args):
    pass
    报错原因：个数可变的关键字参数只能有一个'''

def fun2(*agrs,**args2):
    pass

#def fun(**args1,*args2):
    #pass
'''在一个函数的定义过程中，既有个数可变的关键字形参，也有个数可变的位置形参，要求，个数可变的位置形参放在可变的位置形参之前'''

# %%
def fibonacci(s,count): #定义fib函数的方法较笨
    fib_lst=[0,1]
    fib_part=[]
    if s==0 or s==1:
        fib_part[:]=fib_lst
        for i in range(count-2):
            fib_part.append(fib_part[-1]+fib_part[-2])
    else:
        while True:
            fib_lst[:]=[fib_lst[1],fib_lst[0]+fib_lst[1]]
            #print(fib_lst)
            if fib_lst[1]-s>=0:break
        fib_part[:]=fib_lst
        if abs(fib_lst[0]-s)>=abs(fib_lst[1]-s):
            for i in range(count-1):
                fib_part.append(fib_part[-1]+fib_part[-2])
            fib_part.pop(0)
        else:
            for i in range(count-2):
                fib_part.append(fib_part[-1]+fib_part[-2])
    return fib_part

print("fibonacci(6,9)->{}".format(fibonacci(6,9)))
print("fibonacci(7,9)->{}".format(fibonacci(7,9)))
# Out:
# fibonacci(6,9)->[5, 8, 13, 21, 34, 55, 89, 144, 233]
# fibonacci(7,9)->[8, 13, 21, 34, 55, 89, 144, 233, 377]

# %%
#递归
def factorial(n):
    if n==1:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(7))

#知识点
#递归函数的组成成分：递归调用＋递归终止条件
#在一个函数体内调用了函数本身
def fac(n):
    if n==1:
        return 1
    else:
        res=n*fac(n-1)
        return res
print(fac(6)) #以计算6！为例，调用函数本身

#斐波那契数列
def fib(n):
    if n==1:
        return 1
    elif n==2:
        return 1
    else:
        return fib(n-1)+fib(n-2)
#输出第六位
print(fib(6))

#输出前六位
for i in range(1,7):
    print(fib(i))
# Out:
# 5040

# %%
#类 class
class Bird:
    fly='Whirring' #美 /wɜːr/ 
    def __init__(self):
        self.hungry=True
    def eat(self):
        if self.hungry:
            print('Aaaah...')
            self.hungry=False
        else:
            print('No.Thanks!')

class Apodidae(Bird):  #/'æpədədi:/
    def __init__(self):
        super(Apodidae,self).__init__()
        self.sound='Squawk!' #美 /skwɔːk/ 
    def sing(self):
        print(self.sound)
        
swift=Apodidae()
print("swift.fly->{}".format(swift.fly))
print("swift.eat()->")
swift.eat()
print("swift.eat()->")
swift.eat()
print("swift.sing()->")
swift.sing()

#类与类的实例 
blackswift=Apodidae()
scarceswift=Apodidae()
print("blackswift.sing()->")
blackswift.sing()
print("scarceswift.sing()->")
scarceswift.sing()
#类的属性
print("blackswift.fly->{}".format(blackswift.fly))
blackswift.fly='humming' #重新赋予实例的属性
print("blackswift.fly after redefining the blackswif's attribute->{}".format(blackswift.fly))
print("scarceswift.fly->{}".format(scarceswift.fly))
#类的方法
blackswift.sing()
#超类+子类
# Out:
# swift.fly->Whirring
# swift.eat()->
# Aaaah...
# swift.eat()->
# No.Thanks!
# swift.sing()->
# Squawk!
# blackswift.sing()->
# Squawk!
# scarceswift.sing()->
# Squawk!
# blackswift.fly->Whirring
# blackswift.fly after redefining the blackswif's attribute->humming
# scarceswift.fly->Whirring
# Squawk!
# Help on class Bird in module __main__:
#
# class Bird(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  fly = 'Whirring'
#
# Help on class Apodidae in module __main__:
#
# class Apodidae(Bird)
#  |  Method resolution order:
#  |      Apodidae
#  |      Bird
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  sing(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Bird:
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Bird:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Bird:
#  |
#  |  fly = 'Whirring'

# %%
help(Bird)
# Out:
# Help on class Bird in module __main__:
#
# class Bird(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  fly = 'Whirring'

# %%
help(Apodidae)
# Out:
# Help on class Apodidae in module __main__:
#
# class Apodidae(Bird)
#  |  Method resolution order:
#  |      Apodidae
#  |      Bird
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  sing(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Bird:
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Bird:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Bird:
#  |
#  |  fly = 'Whirring'

# %%
#迭代与迭代器
class Fibs():
    def __init__(self):
        self.a=0
        self.b=1
    def next(self):  #实现迭代器的next方法
        self.a,self.b=self.b,self.a+self.b
        return self.a
    def __iter__(self): #实现迭代方法
        return self
    
f=Fibs()
fa=[]
fb=[]
for i in range(9):
    fa.append(f.next())
print("fa={}".format(fa))
for i in range(5):
    fb.append(f.next())
print("fb={}".format(fb))

#迭代方法往往在机器/深度学习中用于读取数据。import torch.utils.data as Data train_data_iter=Data.DataLoader(train_dataset,batch_size,shuffle=True) #随机读取小批量
# Out:
# fa=[1, 1, 2, 3, 5, 8, 13, 21, 34]
# fb=[55, 89, 144, 233, 377]

# %%
#生成器
#一般方法
lst_e=[list(range(3,20,3)),[3,7,67,list(range(5)),89]]
print("lst_e={}".format(lst_e))
print("_"*50)
flatten_lst=[]
for v_1 in lst_e:
    try:
        for v_2 in v_1:
            try:
                for v_3 in v_2:
                    flatten_lst.append(v_3)
            except TypeError:
                flatten_lst.append(v_2)
    except TypeError:
        flatten_lst.append(v_1)
print("flatten_lst={}".format(flatten_lst))

#生成器方法 使用for循环展平列表，语句表达繁琐，如果存在更多的嵌套或者不可知层次的嵌套列表，需要求助于生成器，一种普遍的函数语法定义的迭代器。
def flatten(lst): #定义生成器（包含yield语句的函数）
    try: #使用语句try\except捕捉异常        
        for n_lst in lst:  #循环列表            
            for m in flatten(n_lst): #使用递归的方法循环子列表                
                yield m  #使用yield语句，每次产生多个值，当返回一个值时函数就会被冻结，当再次激活时，从停止的那点开始执行
    except TypeError:  #当函数被告知展开一个元素时，引发TypeError异常，生成器返回一个值
        yield lst #生成器返回引发异常的一个值        
        
print("list(flatten(lst_e))->{}".format(list(flatten(lst_e))))

flatten_lst=lambda lst:[m for n_lst in lst for m in flatten_lst(n_lst)] if type(lst) is list else [lst] #lambda 生成器方法
# Out:
# lst_e=[[3, 6, 9, 12, 15, 18], [3, 7, 67, [0, 1, 2, 3, 4], 89]]
# __________________________________________________
# flatten_lst=[3, 6, 9, 12, 15, 18, 3, 7, 67, 0, 1, 2, 3, 4, 89]
# list(flatten(lst_e))->[3, 6, 9, 12, 15, 18, 3, 7, 67, 0, 1, 2, 3, 4, 89]

# %%
#建立无穷列表
def infinite():
    n=0
    while True:
        yield 'num#'+str(n)
        n+=1
        
n=infinite()
print("next(n)->{}".format(next(n)))
print("next(n)->{}".format(next(n)))
print("next(n)->{}".format(next(n)))
print("[next(n) for i in range(5)]->{}".format([next(n) for i in range(5)]))

#生成器表达式
n=3
print("[[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->{}".format([[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]))
print("_"*50)
print("([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))->{}".format(([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))))
gen=([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))
print("next(gen)->{}".format(next(gen)))
print("next(gen)->{}".format(next(gen)))
# Out:
# next(n)->num#0
# next(n)->num#1
# next(n)->num#2
# [next(n) for i in range(5)]->['num#3', 'num#4', 'num#5', 'num#6', 'num#7']
# [[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->[[(-6.283185307179586, -6.283185307179586), (0.0, -6.283185307179586), (6.283185307179586, -6.283185307179586)], [(-6.283185307179586, 0.0), (0.0, 0.0), (6.283185307179586, 0.0)], [(-6.283185307179586, 6.283185307179586), (0.0, 6.283185307179586), (6.283185307179586, 6.283185307179586)]]
# __________________________________________________
# ([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))-><generator object <genexpr> at 0x000001D69C8F3BA0>
# next(gen)->[(-6.283185307179586, -6.283185307179586), (0.0, -6.283185307179586), (6.283185307179586, -6.283185307179586)]
# next(gen)->[(-6.283185307179586, 0.0), (0.0, 0.0), (6.283185307179586, 0.0)]

# %%
#try/except 捕捉异常 使用except语句时如果不待任何异常类型，将会捕捉所有异常，但是会捕捉到很多不必要的异常，应该尽量避免使用


'''try:
    do something
except:
    do something'''
    
def f_convert_a(x):
    try:
        return float(x)
    except:
        return x
print("f_convert_a('3.1415')->{}".format(f_convert_a('3.1415')))    
print("f_convert_a('string')->{}".format(f_convert_a('string')))  
print("f_convert_a(3,6,7)->{}".format(f_convert_a((3,6,7))))  

'''try:
    do something
except ValueError:
    do something'''
    
def f_convert_b(x):
    try:
        return float('x')
    except ValueError:
        return x
print("f_convert_b('3.1415')->{}".format(f_convert_b('3.1415')))    
print("f_convert_b('string')->{}".format(f_convert_b('string')))  
print("f_convert_b(3,6,7)->{}".format(f_convert_b((3,6,7))))  

'''try:
    do something
except TypeError:
    do something
except ValueError:
    do something '''
    
def f_convert_c(x):
    try:
        return float(x)
    except ValueError:
        return x
    except TypeError:
        print(x,'TypeError')
print("f_convert_c('3.1415')->{}".format(f_convert_c('3.1415')))    
print("f_convert_c('string')->{}".format(f_convert_c('string')))  
print("f_convert_c(3,6,7)->{}".format(f_convert_c((3,6,7))))       #使用多条except子句可以指定多个异常处理代码块

'''try:
    do something
except (TypeError, ValueError ):
    do something'''
    
def f_open_b(fp):
    try:
        f=open(fp,'r')
    except IOError as e:
        print('Unable to open',fp,':%s\n' %e)
    else:
        data=f.read()
        f.close()
        return data
    finally:
        print('done!')
f_open_b("./data/tryException.txt")     

#知识点总结
'''age=input('请输入你的年龄')
print(type(age))
if age>=18:
    print('成年人')
    报错类型：语法错误 SyntaxError'''

age=input('请输入你的年龄')
print(type(age))
if int(age)>=18:
    print('成年人')

'''解决方案：
1、":"
2、缩进错误
3、中英符号使用错误
4、字符串不和数字拼接
5、“==”和“=”混用'''

#知识不熟练和思路不清（循环）引起的错误
'''lst=[11,22,33,44]
print(lst[4]) 报错类型：索引越界 IndexError'''
lst=[]
#lst=append('a','b')
lst.append('a')
lst.append('b')
print(lst)

#被动掉坑
a=int(input('请输入第一个整数'))
b=int(input('请输入第二个整数'))
result=a/b
print('结果为：',result)

#python的异常处理机制，可以在异常出现时捕获，然后内部消化，让程序继续运行
try:
    a=int(nput('请输入第一个整数'))
    b=int(input('请输入第二个整数'))
    result=a/b
    print('结果为：',result)
except ZeroDivisionError:
    pritn('除数不允许为0')
    print('程序结束')

#多个except结构 捕捉异常的顺序按照先子类后父类的顺序，为了避免遗漏可能出现的异常，可以在最后添加BaseException
try:
    a=int(nput('请输入第一个整数'))
    b=int(input('请输入第二个整数'))
    result=a/b
    print('结果为：',result)
except ZeroDivisionError:
    print('除数不允许为0')
except SyntaxError:
    print('程序结束')
except BaseException as e:
    print(e)

#异常处理机制2 try...except...else。。。finally
#如果try无异常,执行else，如果try有异常，则执行except操作
try:
    a = int(nput('请输入第一个整数'))
    b = int(input('请输入第二个整数'))
    result = a / b
except BaseException as e:
    print('出错了',e)
else:
    print('计算结果为：',result)
finally:
    print('无论结果是否产生异常，总会被执行的代码')
print('程序结束')
# Out:
# f_convert_a('3.1415')->3.1415
# f_convert_a('string')->string
# f_convert_a(3,6,7)->(3, 6, 7)
# f_convert_b('3.1415')->3.1415
# f_convert_b('string')->string
# f_convert_b(3,6,7)->(3, 6, 7)
# f_convert_c('3.1415')->3.1415
# f_convert_c('string')->string
# (3, 6, 7) TypeError
# f_convert_c(3,6,7)->None
# Unable to open ./data/tryException.txt :[Errno 2] No such file or directory: './data/tryException.txt'
#
# done!

# %%
#python内置异常——raise
#raise Exception #没有任何有关错误信息的普通异常
#raise Exception('Computer says no!') #添加错误信息的异常
class some_custom_exception(Exception):pass #
#raise some_custom_exception

#assert断言
x=20
assert x>0 #为真则不做任何事情
#assert x<0 #为假则引发AssertionError异常
# Out:
# Hello
# world
# hello	world
# helloooo	world
# world
# hellworld
# http:\\www.baidu.com
# 老师说：'大家好'
# helllo\bworld
